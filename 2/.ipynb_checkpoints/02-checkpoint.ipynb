# %% [markdown]
# ### Eleonora Bellasio
# # <span style="color:maroon">Laboratorio di Simulazine Numerica: Esercitazione 2

# %% [markdown]
# ### <span style="color:teal">Esercizio 02.1
# Calcolo il valore del seguente integrale utilizzando una distribuzione iniforme in $[0,1]$.
# $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#import math
import os,sys
import math
from scipy.optimize import curve_fit

dinp = "Esercitazione_2/02.1/"
finp1 = dinp + "ese_02_1_pt1.out"
finp2 = dinp + "ese_02_1_pt2.out"

if not os.path.isfile(finp1):
    sys.exit( "file does not exist: " + finp1 )

x, y, error = np.loadtxt(finp1, usecols=(0,2,3), delimiter=' ', unpack='true')

plt.errorbar(x*1000,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('<I>')
#plt.ylim([-0.012,0.02])
plt.grid(True)
plt.show()

# %% [markdown]
# Calcolo il valore dello stesso integrale precedente ma utilizzando il metodo dell'importance sampling. Costruisco una una distribuzione non uniforme in $[0,1]$.
# Volendo cercare una densità di probabilità più simile all'integranda, considero l'espansione in serie di Taylor della funzione $f(x) = \frac{\pi}{2}\cos(\pi x/2) dx = 1$:
# $$\left.\frac{\pi}{2}\cos(\pi x/2)\right|_{x=1} \cong -\left.\left(\frac{\pi}{2}\right)^2\sin(\pi x/2)\right|_{x=1} (x-1) + \mathcal{O}(x^2) \cong - \left(\frac{\pi}{2}\right)^2 (x-1)$$
# Pongo $p(x) = - \left(\frac{\pi}{2}\right)^2 (x-1)$ e trovo che la costante di normalizzazione $C$ per cui si ha che $\int_0^1 C p(x) dx = 1$ è $C=\frac{8}{\pi^2}$.
# Quindi otteniamo un valore di $p(x)$ definitivo pari a:
# $$p(x)= -2x+2 $$
# Dato che possiamo scrivere la seguente uguaglianza
# $$  I= \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = \int_0^1 f(x) d(x) = \int_0^1 g(x) p(x) d(x)$$
# è facile ricavare l'espressione della nuova funzione $g(x)$:
# $$g(x) = \frac{f(x)}{p(x)} = \frac{\pi}{4} \frac{\cos(\pi x/2)}{1-x}$$
# Chiamo $y$ il risultato del calcolo della funzione cumulativa di $p(x)$, questo coincide con il numero casuale che genero tra $[0,1]$. Quindi calcolo la funzione $g(x)$ nei punti $ x = 1 \pm \sqrt{(1-y)}$

# %%
# fare vedere che con la seconda scelta il calcolo è più preciso. Bene figura con incertezze statistiche
# scegliere una probabilità lecita che somigli alla funzione per diminuire la varianza.

if not os.path.isfile(finp2):
    sys.exit( "file does not exist: " + finp2 )

x, y, error = np.loadtxt(finp2, usecols=(0,2,3), delimiter=' ', unpack='true')

plt.errorbar(x*1000,y,yerr=error)
plt.xlabel('#throws')
plt.ylabel('<I>')
#plt.ylim([-0.012,0.02])
plt.grid(True)
plt.show()

# %%
### <span style="color:turquoise">Esercizio 02.2
# Domanda: questo è un comportamento di tipo diffusivo????  Rispondere alla domanda sul testo, fai vedere che va come a per radice di N
# dove N è numero di passi e a coincide con k del testo. Si è un comportamento diffusivo come si può vedere dalle slide 02 a pagina 17
# dove la distanza media al quadrato è = 2Dt = Na2.

dinp = "Esercitazione_2/02.2/"
finp1 = dinp + "ese_02_2_pt1.out"
finp2 = dinp + "ese_02_2_pt2.out"

if not os.path.isfile(finp1):
    sys.exit( "file does not exist: " + finp1 )

x, y, error = np.loadtxt(finp1, usecols=(0,1,2), delimiter=' ', unpack='true')

#Definisco la funzione per il fit
def f(xx, k):
    return k*np.sqrt(xx)

# Bounds specifica i limiti inferiore e superiore in cui cercare il parametro
# p_opt ottimizzano il parametro k che meglio fitta la curva
# p_cov calcola la covarianza dei parametri trovati per calcolare l'incertezza
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
p_opt, p_cov = curve_fit(f, x, y, bounds=(0,  4))

# Valuto la funzione di fit usando il pasametro ottimale
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
y_fit = f(x, p_opt[0])
plt.plot(x, y_fit, color='blue', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 

# Stampo il paramento ottimale e la sua incertezza
print("optimized parameters [k] = " + "{:.4f}".format(p_opt[0]))
print("parameters uncertainty = " + "{:.4f}".format(np.sqrt(np.diagonal(p_cov)[0])))

plt.plot(x,y, color='red', linewidth=4, zorder=0)
plt.xlabel('passi')
plt.ylabel('Distance (lattice units a=1)')
plt.grid(True)
plt.show()
# Out:
# optimized parameters [k] = 1.0011
# parameters uncertainty = 0.0002

# %%
if not os.path.isfile(finp2):
    sys.exit( "file does not exist: " + finp2 )

x, y, error = np.loadtxt(finp2, usecols=(0,1,2), delimiter=' ', unpack='true')

#Definisco la funzione per il fit
def f(xx, k):
    return k*np.sqrt(xx)

# Bounds specifica i limiti inferiore e superiore in cui cercare il parametro
# p_opt ottimizzano il parametro k che meglio fitta la curva
# p_cov calcola la covarianza dei parametri trovati per calcolare l'incertezza
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.curve_fit.html
p_opt, p_cov = curve_fit(f, x, y, bounds=(0,  4))

# Valuto la funzione di fit usando il pasametro ottimale
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
y_fit = f(x, p_opt[0])
plt.plot(x, y_fit, color='blue', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 

# Stampo il paramento ottimale e la sua incertezza
print("optimized parameters [k] = " + "{:.4f}".format(p_opt[0]))
print("parameters uncertainty = " + "{:.4f}".format(np.sqrt(np.diagonal(p_cov)[0])))

plt.errorbar(x,y, color='red', linewidth=4, zorder=0)
plt.xlabel('#throws')
plt.ylabel('Distance (lattice units a=1)')
plt.grid(True)
plt.show()
# Out:
# optimized parameters [k] = 0.9926
# parameters uncertainty = 0.0002
