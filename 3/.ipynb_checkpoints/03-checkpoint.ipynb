# %% [markdown]
# ### Eleonora Bellasio
# # <span style="color:maroon">Laboratorio di Simulazine Numerica: Esercitazione 3

# %% [markdown]
# ### <span style="color:navy">Esercizio 03.1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
#import math
import os,sys
import math
from scipy.optimize import curve_fit

dinp = "Esercitazione_3/03.1/"
finp1 = dinp + "ese_03_1_pt1_C.out"
finp2 = dinp + "ese_03_1_pt1_P.out"
finp3 = dinp + "ese_03_1_pt2_C.out"
finp4 = dinp + "ese_03_1_pt2_P.out"

if not os.path.isfile(finp1):
    sys.exit( "file does not exist: " + finp1 )
    
x, y, error = np.loadtxt(finp1, usecols=(0,2,3), delimiter=' ', unpack='true')

plt.errorbar(x*100,y,yerr=error)
plt.axhline(y=14.975790778311286, color="darkorange", linestyle="--")
plt.xlabel(' ')
plt.ylabel('European call-option prices')
plt.grid(True)
plt.show()

if not os.path.isfile(finp2):
    sys.exit( "file does not exist: " + finp2 )

x, y, error = np.loadtxt(finp2, usecols=(0,2,3), delimiter=' ', unpack='true')

plt.errorbar(x*100,y,yerr=error)
plt.axhline(y=5.4595325819072364, color="darkorange", linestyle="--")
plt.xlabel(' ')
plt.ylabel('European put-option prices')
plt.grid(True)
plt.show()

# %%
if not os.path.isfile(finp3):
    sys.exit( "file does not exist: " + finp3 )

x, y, error = np.loadtxt(finp3, usecols=(0,2,3), delimiter=' ', unpack='true')

plt.errorbar(x*100,y,yerr=error)
plt.axhline(y=14.975790778311286, color="darkorange", linestyle="--")
plt.xlabel(' ')
plt.ylabel('European call-option prices')
plt.grid(True)
plt.show()

if not os.path.isfile(finp4):
    sys.exit( "file does not exist: " + finp4 )

x, y, error = np.loadtxt(finp4, usecols=(0,2,3), delimiter=' ', unpack='true')

plt.errorbar(x*100,y,yerr=error)
plt.axhline(y=5.4595325819072364, color="darkorange", linestyle="--")
plt.xlabel(' ')
plt.ylabel('European put-option prices')
plt.grid(True)
plt.show()
