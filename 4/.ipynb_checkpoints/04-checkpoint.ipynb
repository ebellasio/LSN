# %% [markdown]
# ### Eleonora Bellasio
# # <span style="color:maroon">Laboratorio di Simulazine Numerica: Esercitazione 4

# %% [markdown]
# ### <span style="color:turquoise">Esercizio 04.1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import os,sys
import pandas as pd

dinp = "Esercitazione_4/04.1/OUTPUT/"
finp1 = dinp + "pofv.dat"

v_max = 5  #Deve essere come nel cpp
T = 2    #Deve essere come nel cpp

if not os.path.isfile(finp1):
    sys.exit( "file does not exist: " + finp1 )

#Metto i dati di output in un dataframe
#Elimino la riga iniziale perchè lo # sfasa le colonne (in alternativa potrei modificare l'output del cpp)
#Indico che il separatore di campo non è la virgola (default) ma una serie di spazi
#Siccome ho eliminato l'intestazione ricreo l'header con name=[...]
df = pd.read_csv(finp1, skiprows=1, sep='\\s+', names=['BLOCK:','POFV:','AVE_POFV:','ERROR:'])
#print (df)
#Filtro i dati di alcuni blocchi precedenti all'ultimo per mostrare l'evoluzione della distribuzuine
df_block01 = df[df['BLOCK:'] == 1]
df_block10 = df[df['BLOCK:'] == 10]
df_block15 = df[df['BLOCK:'] == 15]
#Filtro i dati dell'ultimo blocco per ricavare l'ultimo grafico
df_block20 = df[df['BLOCK:'] == 20]
#print (df_block20)

#Definisco la funzione analitica della distribuzione di Maxwell-Boltzmann per il fit
#xx è la variabile v*, k è il parametro temperatura
def f(xx, k):
    return (1/pow(2*math.pi*k,3/2))*4*math.pi*(xx**2)*math.exp((-xx**2)/(2*k))

#Ricavo il numero di bin dal grafico
n_bins = len(df_block20['BLOCK:'])
#Ricavo il passo tra bin successivi e di conseguenza imposto le x
step = v_max / n_bins
x = np.arange(0,v_max,step)
#print (x)

# Valuto la funzione di fit usando lo stesso parametro temperatura del cpp
#Trasformo f in un vettore (f2) per renderla compatibile con le x
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
f2 = np.vectorize(f)
y_fit = f2(x, T)

#Primo blocco
plt.errorbar(x,df_block01['AVE_POFV:'],yerr=df_block01['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°1")
plt.show()

#Decimo blocco
plt.errorbar(x,df_block10['AVE_POFV:'],yerr=df_block10['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°10")
plt.show()

#Quindicesimo blocco
plt.errorbar(x,df_block15['AVE_POFV:'],yerr=df_block15['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°15")
plt.show()

#Ultimo blocco
plt.errorbar(x,df_block20['AVE_POFV:'],yerr=df_block20['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°20")
plt.show()

# %%
dinp = "Esercitazione_4/04.2/OUTPUT/"
finp2 = dinp + "pofv.dat"

v_max = 5  #Deve essere come nel cpp
T = 1.37379    #Deve essere come nel cpp

if not os.path.isfile(finp2):
    sys.exit( "file does not exist: " + finp2 )

#Metto i dati di output in un dataframe
#Elimino la riga iniziale perchè lo # sfasa le colonne (in alternativa potrei modificare l'output del cpp)
#Indico che il separatore di campo non è la virgola (default) ma una serie di spazi
#Siccome ho eliminato l'intestazione ricreo l'header con name=[...]
df = pd.read_csv(finp2, skiprows=1, sep='\\s+', names=['BLOCK:','POFV:','AVE_POFV:','ERROR:'])
#print (df)
#Filtro i dati di alcuni blocchi precedenti all'ultimo per mostrare l'evoluzione della distribuzuine
df_block01 = df[df['BLOCK:'] == 1]
df_block10 = df[df['BLOCK:'] == 10]
df_block15 = df[df['BLOCK:'] == 15]
#Filtro i dati dell'ultimo blocco per ricavare l'ultimo grafico
df_block20 = df[df['BLOCK:'] == 20]
#print (df_block20)

#Definisco la funzione analitica della distribuzione di Maxwell-Boltzmann per il fit
#xx è la variabile v*, k è il parametro temperatura
def f(xx, k):
    return (1/pow(2*math.pi*k,3/2))*4*math.pi*(xx**2)*math.exp((-xx**2)/(2*k))

#Ricavo il numero di bin dal grafico
n_bins = len(df_block20['BLOCK:'])
#Ricavo il passo tra bin successivi e di conseguenza imposto le x
step = v_max / n_bins
x = np.arange(0,v_max,step)
#print (x)

# Valuto la funzione di fit usando lo stesso parametro temperatura del cpp
#Trasformo f in un vettore (f2) per renderla compatibile con le x
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
f2 = np.vectorize(f)
y_fit = f2(x, T)

#Primo blocco
plt.errorbar(x,df_block01['AVE_POFV:'],yerr=df_block01['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°1")
plt.show()

#Decimo blocco
plt.errorbar(x,df_block10['AVE_POFV:'],yerr=df_block10['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°10")
plt.show()

#Quindicesimo blocco
plt.errorbar(x,df_block15['AVE_POFV:'],yerr=df_block15['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°15")
plt.show()

#Ultimo blocco
plt.errorbar(x,df_block20['AVE_POFV:'],yerr=df_block20['ERROR:'])
plt.plot(x, y_fit, color='coral', marker='o', linestyle='none', linewidth=2, markersize=2, zorder=1) 
plt.xlabel('#velocity (m/s)')
plt.ylabel('Maxwell–Boltzmann distribution $p(v^*,T^*)$')
plt.grid(True)
plt.title("Block N°20")
plt.show()
